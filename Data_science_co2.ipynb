# %% [raw]
# https://www.kaggle.com/datasets/debajyotipodder/co2-emission-by-vehicles

# %%
path = r'C:\Users\sudar\Documents/CO2 Emissions_Canada.csv'
path
# Out:
# 'C:\\Users\\sudar\\Documents/CO2 Emissions_Canada.csv'

# %%
# import ds libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv(path)
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %% [raw]
# pd.read_ #hit the tab after this u will get further suggestions

# %%
df = pd.read_csv(path)
df.head(2)
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX       COMPACT             2.0          4          AS5
# 1  ACURA   ILX       COMPACT             2.4          4           M6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221

# %%
# check number of rows n columns
df.shape
# Out:
# (7385, 12)

# %%
# display column names
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
# summary of dataset
# Print a concise summary of a DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
# select any one column
#df.Model
#df['Model']
#df[['Model']]
df[['Model','CO2 Emissions(g/km)']]
# Out:
#             Model  CO2 Emissions(g/km)
# 0             ILX                  196
# 1             ILX                  221
# 2      ILX HYBRID                  136
# 3         MDX 4WD                  255
# 4         RDX AWD                  244
# ...           ...                  ...
# 7380  XC40 T5 AWD                  219
# 7381  XC60 T5 AWD                  232
# 7382  XC60 T6 AWD                  240
# 7383  XC90 T5 AWD                  232
# 7384  XC90 T6 AWD                  248
#
# [7385 rows x 2 columns]

# %%
# work on Model column
df.Model.unique()
# Out:
# array(['ILX', 'ILX HYBRID', 'MDX 4WD', ...,
#        'Tacoma 4WD D-Cab TRD Off-Road/Pro', 'Atlas Cross Sport 4MOTION',
#        'XC40 T4 AWD'], dtype=object)

# %%
# count unique models
df.Model.nunique()
# Out:
# 2053

# %%
# display per model count
df.Model.value_counts()
# Out:
# Model
# F-150 FFV 4X4           32
# F-150 FFV               32
# MUSTANG                 27
# FOCUS FFV               24
# SONIC                   20
#                         ..
# AVENTADOR S ROADSTER     1
# HURACAN AWD              1
# HURACAN SPYDER AWD       1
# LS 500                   1
# XC40 T4 AWD              1
# Name: count, Length: 2053, dtype: int64

# %%
df.Model.value_counts().head(10)
# Out:
# Model
# F-150 FFV 4X4    32
# F-150 FFV        32
# MUSTANG          27
# FOCUS FFV        24
# SONIC            20
# SONIC 5          20
# F-150 4X4        20
# F-150            20
# ACCORD           19
# COMPASS          19
# Name: count, dtype: int64

# %%
# plot
df.Model.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
# sort Model column A-Z
df.Model.sort_values()
# Out:
# 3617    124 SPIDER
# 3618    124 SPIDER
# 4681    124 SPIDER
# 4680    124 SPIDER
# 6773    124 Spider
#            ...
# 2071            xB
# 940             xB
# 939             xB
# 942             xD
# 941             xD
# Name: Model, Length: 7385, dtype: object

# %%
# select model names starting with M
df[df.Model.str.startswith('M')]
# Out:
#          Make       Model             Vehicle Class  Engine Size(L)  \
# 3       ACURA     MDX 4WD               SUV - SMALL             3.5
# 75    BENTLEY    MULSANNE                  MID-SIZE             6.8
# 118       BMW          M5                  MID-SIZE             4.4
# 119       BMW          M5                  MID-SIZE             4.4
# 120       BMW          M6                   COMPACT             4.4
# ...       ...         ...                       ...             ...
# 7231   NISSAN      Maxima                  MID-SIZE             3.5
# 7232   NISSAN      Murano  STATION WAGON - MID-SIZE             3.5
# 7233   NISSAN  Murano AWD  STATION WAGON - MID-SIZE             3.5
# 7257  PORSCHE       Macan               SUV - SMALL             2.0
# 7258  PORSCHE     Macan S               SUV - SMALL             3.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 3             6          AS6         Z                              12.7
# ...

# %%
df[df.Model.str.startswith('M')][['Model']]
# Out:
#            Model
# 3        MDX 4WD
# 75      MULSANNE
# 118           M5
# 119           M5
# 120           M6
# ...          ...
# 7231      Maxima
# 7232      Murano
# 7233  Murano AWD
# 7257       Macan
# 7258     Macan S
#
# [534 rows x 1 columns]

# %%
# check data types of columns
df.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %%
# select object columns
df.select_dtypes('object')
# Out:
#        Make        Model   Vehicle Class Transmission Fuel Type
# 0     ACURA          ILX         COMPACT          AS5         Z
# 1     ACURA          ILX         COMPACT           M6         Z
# 2     ACURA   ILX HYBRID         COMPACT          AV7         Z
# 3     ACURA      MDX 4WD     SUV - SMALL          AS6         Z
# 4     ACURA      RDX AWD     SUV - SMALL          AS6         Z
# ...     ...          ...             ...          ...       ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL          AS8         Z
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL          AS8         Z
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL          AS8         Z
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD          AS8         Z
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD          AS8         Z
#
# [7385 rows x 5 columns]

# %%
df['Vehicle Class']
# Out:
# 0              COMPACT
# 1              COMPACT
# 2              COMPACT
# 3          SUV - SMALL
# 4          SUV - SMALL
#              ...
# 7380       SUV - SMALL
# 7381       SUV - SMALL
# 7382       SUV - SMALL
# 7383    SUV - STANDARD
# 7384    SUV - STANDARD
# Name: Vehicle Class, Length: 7385, dtype: object

# %%
# unique record count in each object column
obj = df.select_dtypes('object').columns
obj
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Transmission', 'Fuel Type'], dtype='object')

# %%
#df[colun_name].nunique()
cnt = []
for col in obj:
    #print(col)
    cnt.append(df[col].nunique())
    print(col,':',df[col].nunique())
# Out:
# Make : 42
# Model : 2053
# Vehicle Class : 16
# Transmission : 27
# Fuel Type : 5

# %%
d = pd.DataFrame(data=obj)
d['unique'] = cnt
d
# Out:
#                0  unique
# 0           Make      42
# 1          Model    2053
# 2  Vehicle Class      16
# 3   Transmission      27
# 4      Fuel Type       5

# %% [markdown]
# ### What are the car brands do we have?

# %%
print("We have total",len(df['Make'].unique()),"Car Companies Data")
df_brand = df['Make'].value_counts().reset_index().rename(columns={'count':'Count'})
df_brand.head(25)
# Out:
# We have total 42 Car Companies Data
#              Make  Count
# 0            FORD    628
# 1       CHEVROLET    588
# 2             BMW    527
# 3   MERCEDES-BENZ    419
# 4         PORSCHE    376
# 5          TOYOTA    330
# 6             GMC    328
# 7            AUDI    286
# 8          NISSAN    259
# 9            JEEP    251
# 10          DODGE    246
# 11            KIA    231
# 12          HONDA    214
# 13        HYUNDAI    210
# 14           MINI    204
# 15     VOLKSWAGEN    197
# 16          MAZDA    180
# 17          LEXUS    178
# 18         JAGUAR    160
# 19       CADILLAC    158
# 20         SUBARU    140
# 21          VOLVO    124
# 22       INFINITI    108
# 23          BUICK    103
# 24            RAM     97

# %%
plt.figure(figsize=(20,6))
figure1 = sns.barplot(data = df_brand, x = "Make",  y= "Count")
plt.xticks(rotation = 75)
plt.title("All Car Companies and their Cars")
plt.xlabel("Companies")
plt.ylabel("Cars")
plt.bar_label(figure1.containers[0])
plt.show()

# %% [markdown]
# #### Which Model have highest co2 emission?

# %%
df.sort_values(by ="CO2 Emissions(g/km)", ascending= False).head(7)
# Out:
#              Make               Model    Vehicle Class  Engine Size(L)  \
# 5575      BUGATTI              Chiron       TWO-SEATER             8.0
# 6640      BUGATTI              Chiron       TWO-SEATER             8.0
# 4509      BUGATTI              CHIRON       TWO-SEATER             8.0
# 7059  LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 6046  LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 349          FORD          E350 WAGON  VAN - PASSENGER             6.8
# 6045  LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 5575         16          AM7         Z                              26.8
# 6640         16          AM7         Z                              26.8
# 4509         16          AM7         Z                              26.8
# 7059         12          AM7         Z                              26.6
# ...

# %%
plt.figure(figsize=(10,10))
figure1 = sns.pairplot(data = df)
plt.show()
# Out:
# C:\Users\sudar\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print("We have total",len(df['Vehicle Class'].unique()),"Vehicle Class")
df_vehicle_class = df['Vehicle Class'].value_counts().reset_index().rename(columns={'count':'Count'})
df_vehicle_class
# Out:
# We have total 16 Vehicle Class
#                Vehicle Class  Count
# 0                SUV - SMALL   1217
# 1                   MID-SIZE   1133
# 2                    COMPACT   1022
# 3             SUV - STANDARD    735
# 4                  FULL-SIZE    639
# 5                 SUBCOMPACT    606
# 6    PICKUP TRUCK - STANDARD    538
# 7                 TWO-SEATER    460
# 8                MINICOMPACT    326
# 9      STATION WAGON - SMALL    252
# 10      PICKUP TRUCK - SMALL    159
# 11                   MINIVAN     80
# 12   SPECIAL PURPOSE VEHICLE     77
# 13           VAN - PASSENGER     66
# 14  STATION WAGON - MID-SIZE     53
# 15               VAN - CARGO     22

# %% [markdown]
# #### Engine Sizes of Car

# %%
print("We have",len(df['Engine Size(L)'].value_counts()), "different sizes of Engine")
# Out:
# We have 51 different sizes of Engine

# %%
df_engine_size = df['Engine Size(L)'].value_counts().reset_index().rename(columns={'count':'Count'})
df_engine_size
# Out:
#     Engine Size(L)  Count
# 0              2.0   1460
# 1              3.0    804
# 2              3.6    536
# 3              3.5    529
# 4              2.5    423
# 5              2.4    346
# 6              1.6    302
# 7              5.3    290
# 8              1.8    216
# 9              1.4    211
# 10             5.0    207
# 11             1.5    207
# 12             4.0    198
# 13             6.2    162
# 14             4.4    131
# 15             5.7    116
# 16             3.8    114
# 17             3.7    112
# 18             2.7     99
# 19             6.0     94
# 20             3.3     85
# 21             4.7     78
# 22             3.4     52
# 23             5.5     52
# 24             4.3     52
# 25             2.3     51
# 26             5.2     48
# 27             6.4     46
# 28             5.6     36
# 29             3.2     35
# 30             4.8     32
# 31             4.6     32
# 32             6.6     29
# 33             1.2     25
# ...

# %%
df[df['Engine Size(L)'] == 8.4]
# Out:
#        Make            Model Vehicle Class  Engine Size(L)  Cylinders  \
# 945     SRT      VIPER COUPE    TWO-SEATER             8.4         10
# 946     SRT  VIPER GTS COUPE    TWO-SEATER             8.4         10
# 1431  DODGE  VIPER SRT COUPE    TWO-SEATER             8.4         10
# 2544  DODGE        VIPER SRT    TWO-SEATER             8.4         10
# 3616  DODGE            VIPER    TWO-SEATER             8.4         10
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 945            M6         Z                              20.0
# 946            M6         Z                              20.0
# 1431           M6         Z                              19.4
# 2544           M6         Z                              19.2
# 3616           M6         Z                              19.9
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 945                              13.0                              16.9
# ...

# %%
plt.figure(figsize=(20,6))
figure4 = sns.barplot(data = df_engine_size, x = "Engine Size(L)",  y= "Count")
plt.xticks(rotation = 90)
plt.title("All Engine Sizes")
plt.xlabel("Engine Size(L)")
plt.ylabel("Cars")
plt.bar_label(figure4.containers[0])
plt.show()
